# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
covid=pd.read_csv("country_wise_latest.csv")

covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
print(covid)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
covid.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
covid['Deaths'].hist()

# %%
covid['Deaths'].plot.kde()

# %%
covid[['Confirmed','Deaths','Recovered']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f50cca65a20>,
# ...
#       dtype=object)

# %%
americas_covid=covid[(covid['WHO Region']=='Americas')]
americas_covid
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered   Active  \
# 5                 Antigua and Barbuda         86       3         65       18
# 6                           Argentina     167416    3059      72575    91782
# 11                            Bahamas        382      11         91      280
# 14                           Barbados        110       7         94        9
# 17                             Belize         48       2         26       20
# 20                            Bolivia      71181    2647      21478    47056
# 23                             Brazil    2442375   87618    1846641   508116
# 32                             Canada     116458    8944          0   107514
# 35                              Chile     347923    9187     319954    18782
# 37                           Colombia     257101    8777     131161   117163
# 41                         Costa Rica      15841     115       3824    11902
# ...

# %%
import matplotlib.pyplot as plt

us_covid=covid[(covid['Country/Region']=='US')]
us_covid
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
westbank_gaza_covid=covid[(covid['Country/Region']=='West Bank and Gaza')]
westbank_gaza_covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 182                    2.08                 8916           1705
#
#      1 week % increase             WHO Region
# 182              19.12  Eastern Mediterranean

# %%
import matplotlib.pyplot as plt

us_covid=covid[(covid['Country/Region']=='US')]
us_covid.groupby(['Deaths'])(['Recovered'].plot.kde()
plt.legend()
# Out:
#   File "<ipython-input-14-6dfc57b80103>", line 5
#     plt.legend()
#       ^
# SyntaxError: invalid syntax
