# %% [markdown]
# # Week 10 Assignment
#
# Because I was unable to conduct our workshop this week, I'm keeping the assignment light as well.  Below you'll find just two steps for this week: one programming exercise and then a planning activity for your final project.
#
# For clarification, the "final project" I've been referring to is your "final."  It is not a project in addition to a final exam.  They're one-in-the-same.
#
# Please do the programming exercise and verify that your code works using the tests, then think about your final project and fill out the questions in the second part.
#
# ---
# ---

# %% [markdown]
# ### 47.1: Filtering and summarizing data
#
# For this work, you'll find a data file in `/data/complications_all.csv`.
#
# Read in the data file and create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# Then aggregate that data by hospital into a variable named `mo_summary`.  There are some key fields that we want to summarize:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
#
# You do not need to create your code in the form of a function, just make sure your variable names match what I've described above so the tests work.

# %%
import pandas as pd
import datetime as dt
# This is just to show you the name to use for the variable you need to create for this step to pass.
data = pd.read_csv('complications_all.csv')
data
# Out:
#       Facility ID                                      Facility Name  \
# 0          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 2          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 3          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 4          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                                ...
# 91390      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91391      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91392      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91393      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91394      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# ...

# %%
filt=data['State']=='MO'
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91390    False
# 91391    False
# 91392    False
# 91393    False
# 91394    False
# Name: State, Length: 91395, dtype: bool

# %%
filt.value_counts()
# Out:
# False    89262
# True      2133
# Name: State, dtype: int64

# %%
mo_hospitals=data[filt]

# %%
mo_hospitals.head()
# Out:
#       Facility ID          Facility Name        Address    City State  \
# 45534      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45535      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45536      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45537      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45538      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
#
#        ZIP Code County Name    Phone Number     Measure ID  \
# 45534     64804      JASPER  (417) 781-2727  COMP_HIP_KNEE
# 45535     64804      JASPER  (417) 781-2727    MORT_30_AMI
# 45536     64804      JASPER  (417) 781-2727   MORT_30_CABG
# 45537     64804      JASPER  (417) 781-2727   MORT_30_COPD
# 45538     64804      JASPER  (417) 781-2727     MORT_30_HF
#
#                                             Measure Name  \
# 45534  Rate of complications for hip/knee replacement...
# 45535               Death rate for heart attack patients
# ...

# %%
mo_hospitals.shape
# Out:
# (2133, 18)

# %%
mo_hospitals['Facility Name'].unique()
# Out:
# array(['MERCY HOSPITAL JOPLIN', 'COOPER COUNTY COMMUNITY HOSPITAL',
#        'SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES',
#        'MOSAIC LIFE CARE AT ST JOSEPH', 'BOTHWELL REGIONAL HEALTH CENTER',
#        "SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY", 'PHELPS HEALTH',
#        'MERCY HOSPITAL ST LOUIS', 'NORTHEAST REGIONAL MEDICAL CENTER',
#        'MERCY HOSPITAL JEFFERSON', 'TEXAS COUNTY MEMORIAL HOSPITAL',
#        'HANNIBAL REGIONAL HOSPITAL', 'RESEARCH MEDICAL CENTER',
#        'General Leonard Wood ACH (FT Leonard Wood)',
#        'BARNES JEWISH HOSPITAL', 'BATES COUNTY MEMORIAL HOSPITAL',
#        'COX MEDICAL CENTERS', 'CAPITAL REGION MEDICAL CENTER',
#        'TRUMAN MEDICAL CENTER HOSPITAL HILL',
#        'KANSAS CITY VA MEDICAL CENTER',
#        'MOSAIC MEDICAL CENTER - MARYVILLE', 'MERCY HOSPITAL WASHINGTON',
#        'CAMERON REGIONAL MEDICAL CENTER', 'MERCY HOSPITAL LEBANON',
#        'NEVADA REGIONAL MEDICAL CENTER', 'SAINT LUKES NORTH HOSPITAL',
# ...

# %%
# These assertions will help make sure that you're on the right track.
assert(mo_hospitals['State'].unique() == ['MO'])
assert(mo_hospitals.shape == (2133,18))

# %%
# read CSV and pick Missouri data, group by Facility
all_data = pd.read_csv('complications_all.csv')
where_state_is_MO = all_data['State'] == 'MO'
mo_data: pd.DataFrame = all_data[where_state_is_MO]
mo_data = mo_data[mo_data['Denominator'] != 'Not Available']
mo_hospitals = mo_data.groupby('Facility ID')
# Declare needed data for Pandas output
index = []
data_for_dataframe = { # 108 rows, 3 columns
    "number": [],
    "start_date": [],
    "end_date": []
}

# Loop over many hospitals
for facility_id, hospital in mo_hospitals:
    # Loop over duplicate rows of one hospital
    patients_in_hospital = 0
    for denominator in hospital['Denominator']:
        patients_in_hospital = patients_in_hospital + int(denominator)

    earliest_start_date_found = None
    for date in hospital['Start Date']: # Search for the smallest date
        iso_date_string = f"{date[6:10]}-{date[0:2]}-{date[3:5]}" # converted CSV dates to ISO date
        iso_date = dt.datetime.strptime(iso_date_string, "%Y-%m-%d")
        if (earliest_start_date_found is None or iso_date < earliest_start_date_found):
            earliest_start_date_found = iso_date

    latest_end_date_found = None
    for date in hospital['End Date']: # Search for the largest date
        iso_date_string = f"{date[6:10]}-{date[0:2]}-{date[3:5]}" # converted CSV dates to ISO date
        iso_date = dt.datetime.strptime(iso_date_string, "%Y-%m-%d")
        if (latest_end_date_found is None or iso_date < latest_end_date_found):
            latest_end_date_found = iso_date

    index += [str(hospital['Facility Name'].values[0])]
    data_for_dataframe["number"] += [patients_in_hospital]
    data_for_dataframe["start_date"] += [earliest_start_date_found]
    data_for_dataframe["end_date"] += [latest_end_date_found]

mo_summary = pd.DataFrame(data=data_for_dataframe, index=index)
print(mo_summary)
# Out:
#                                           number start_date   end_date
# MERCY HOSPITAL JOPLIN                      29977 2015-04-01 2018-03-31
# COOPER COUNTY COMMUNITY HOSPITAL             697 2015-07-01 2018-06-30
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES   23443 2015-04-01 2018-03-31
# MOSAIC LIFE CARE AT ST JOSEPH              54860 2015-04-01 2018-03-31
# BOTHWELL REGIONAL HEALTH CENTER            14717 2015-04-01 2018-03-31
# ...                                          ...        ...        ...
# I-70 COMMUNITY HOSPITAL                       26 2015-07-01 2018-06-30
# MERCY ST FRANCIS HOSPITAL                     60 2015-07-01 2018-06-30
# IRON COUNTY MEDICAL CENTER                    99 2015-07-01 2018-06-30
# MISSOURI BAPTIST SULLIVAN HOSPITAL           275 2015-07-01 2018-06-30
# MERCY HOSPITAL CARTHAGE                      153 2015-07-01 2018-06-30
#
# [108 rows x 3 columns]

# %%
mo_summary
# Out:
#                                           number start_date   end_date
# MERCY HOSPITAL JOPLIN                      29977 2015-04-01 2018-03-31
# COOPER COUNTY COMMUNITY HOSPITAL             697 2015-07-01 2018-06-30
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES   23443 2015-04-01 2018-03-31
# MOSAIC LIFE CARE AT ST JOSEPH              54860 2015-04-01 2018-03-31
# BOTHWELL REGIONAL HEALTH CENTER            14717 2015-04-01 2018-03-31
# ...                                          ...        ...        ...
# I-70 COMMUNITY HOSPITAL                       26 2015-07-01 2018-06-30
# MERCY ST FRANCIS HOSPITAL                     60 2015-07-01 2018-06-30
# IRON COUNTY MEDICAL CENTER                    99 2015-07-01 2018-06-30
# MISSOURI BAPTIST SULLIVAN HOSPITAL           275 2015-07-01 2018-06-30
# MERCY HOSPITAL CARTHAGE                      153 2015-07-01 2018-06-30
#
# [108 rows x 3 columns]

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)

# %% [markdown]
# ---
#
# ### 47.2 Planning your final project
#
# You should be thinking about the things we've been learning and how you can apply them to your final project.  Use the rubric to help guid your thinking and then answer the questions below.  This is meant as a guide to help you think through what you will do.

# %% [markdown]
# #### A) Data Access
#
# Your project should include data from at least three distinct types of sources.  For example: AWS S3, Relational Databases, Internet, Web Services, local files.  List what data sources you're planning to use.

# %% [markdown]
# The data sources I plan on using for the project is going to be from the internet. I have been looking on for data cdc, and possibly github and kaggle. Im still looking for other, reliable sources.

# %% [markdown]
# #### B. Data Formats
#
# Your project should include data that comes in different file formats.  For example: HL7, EDI, HTML, CSV, Excel, JSON, XML.  List what data formats you're planning to use.

# %% [markdown]
# My plan for data formats using json, csv, and excel for this project. Maybe on merging all the files in to a single dataframe. I am still thinking on what I am trying to do with all the files.

# %% [markdown]
# #### C. Objective
#
# What purpose would your project serve in a real work setting?  Take a couple of paragraphs to write down why this is an interesting product.

# %% [markdown]
#    I plan on gathering information, on covid19, population size, and obesity.I want to show what areas were impacted on by covid19. Then I would should if those cities already high obesity rate. Then a correlation test would show if a city's obesity has a correlation on the high counts of Covid19. I would want to display that as a scatter plot or bar graph with a correlation test.
#    The same would apply with population. Perfrom a a correlation test and use charts to compare every state or city in America. Then after the correlation test and printing the graphs, I want to add those correletions between obesity and covid and populaiton size and covid in two new columns showing the correlation score for every city or state. This would probably done using mulitple for loops to accomplish .

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-cef8011cb395> in <module>
# ----> 1 assert False, "DO NOT REMOVE THIS LINE"
#
# AssertionError: DO NOT REMOVE THIS LINE

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week10_assignment_2.ipynb
# git commit -a -m "Submitting the week 10 programming assignment"
# git push
# Out:
# Already up to date.
# [main d312c8a] Submitting the week 10 programming assignment
#  2 files changed, 874 insertions(+), 2 deletions(-)
#  create mode 100644 week10/week10_assignment_2.ipynb
# To github.com:majdhamed/hds5210-2021.git
#    dc77295..d312c8a  main -> main

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 8 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
