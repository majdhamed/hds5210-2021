# %%
import pandas as pd


data = pd.read_csv('complications_all.csv')
data
# Out:
#       Facility ID                                      Facility Name  \
# 0          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 2          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 3          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 4          010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                                ...
# 91390      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91391      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91392      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91393      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
# 91394      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER  PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# ...

# %%
data.head()
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number     Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  COMP_HIP_KNEE
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701    MORT_30_AMI
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_CABG
# 3  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_COPD
# 4  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     MORT_30_HF
#
#                                         Measure Name  \
# 0  Rate of complications for hip/knee replacement...
# ...

# %%
filt=data['State']=='MO'
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91390    False
# 91391    False
# 91392    False
# 91393    False
# 91394    False
# Name: State, Length: 91395, dtype: bool

# %%
filt.value_counts()
# Out:
# False    89262
# True      2133
# Name: State, dtype: int64

# %%
mo_only=data[filt]

# %%
mo_only.head()
# Out:
#       Facility ID          Facility Name        Address    City State  \
# 45534      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45535      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45536      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45537      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45538      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
#
#        ZIP Code County Name    Phone Number     Measure ID  \
# 45534     64804      JASPER  (417) 781-2727  COMP_HIP_KNEE
# 45535     64804      JASPER  (417) 781-2727    MORT_30_AMI
# 45536     64804      JASPER  (417) 781-2727   MORT_30_CABG
# 45537     64804      JASPER  (417) 781-2727   MORT_30_COPD
# 45538     64804      JASPER  (417) 781-2727     MORT_30_HF
#
#                                             Measure Name  \
# 45534  Rate of complications for hip/knee replacement...
# 45535               Death rate for heart attack patients
# ...

# %%
print(mo_only.shape)
# Out:
# (2133, 18)

# %%
mo_only['Facility Name'].unique()
# Out:
# array(['MERCY HOSPITAL JOPLIN', 'COOPER COUNTY COMMUNITY HOSPITAL',
#        'SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES',
#        'MOSAIC LIFE CARE AT ST JOSEPH', 'BOTHWELL REGIONAL HEALTH CENTER',
#        "SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY", 'PHELPS HEALTH',
#        'MERCY HOSPITAL ST LOUIS', 'NORTHEAST REGIONAL MEDICAL CENTER',
#        'MERCY HOSPITAL JEFFERSON', 'TEXAS COUNTY MEMORIAL HOSPITAL',
#        'HANNIBAL REGIONAL HOSPITAL', 'RESEARCH MEDICAL CENTER',
#        'General Leonard Wood ACH (FT Leonard Wood)',
#        'BARNES JEWISH HOSPITAL', 'BATES COUNTY MEMORIAL HOSPITAL',
#        'COX MEDICAL CENTERS', 'CAPITAL REGION MEDICAL CENTER',
#        'TRUMAN MEDICAL CENTER HOSPITAL HILL',
#        'KANSAS CITY VA MEDICAL CENTER',
#        'MOSAIC MEDICAL CENTER - MARYVILLE', 'MERCY HOSPITAL WASHINGTON',
#        'CAMERON REGIONAL MEDICAL CENTER', 'MERCY HOSPITAL LEBANON',
#        'NEVADA REGIONAL MEDICAL CENTER', 'SAINT LUKES NORTH HOSPITAL',
# ...

# %%
mo_only['Denominator'].value_counts()
# Out:
# Not Available    944
# 26                 7
# 77                 7
# 75                 7
# 46                 6
#                 ...
# 780                1
# 13429              1
# 2294               1
# 1622               1
# 999                1
# Name: Denominator, Length: 801, dtype: int64

# %%
sum_denominator=mo_only.sum(axis=0)
sum_denominator
# Out:
# Facility ID             2600012600012600012600012600012600012600012600...
# Facility Name           MERCY HOSPITAL JOPLINMERCY HOSPITAL JOPLINMERC...
# Address                 100 MERCY WAY100 MERCY WAY100 MERCY WAY100 MER...
# City                    JOPLINJOPLINJOPLINJOPLINJOPLINJOPLINJOPLINJOPL...
# State                   MOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMOMO...
# ZIP Code                                                        137007750
# County Name             JASPERJASPERJASPERJASPERJASPERJASPERJASPERJASP...
# Phone Number            (417) 781-2727(417) 781-2727(417) 781-2727(417...
# Measure ID              COMP_HIP_KNEEMORT_30_AMIMORT_30_CABGMORT_30_CO...
# Measure Name            Rate of complications for hip/knee replacement...
# Compared to National    No Different Than the National RateNo Differen...
# Denominator             2617591326461638222736419192068944213355988209...
# Score                   2.513.92.58.513.118.313.61.104.442.104.861.080...
# ...

# %%
len(mo_only['Denominator'].unique())
# Out:
# 801

# %%
mo_only['Denominator'].value_counts()
# Out:
# Not Available    944
# 26                 7
# 77                 7
# 75                 7
# 46                 6
#                 ...
# 780                1
# 13429              1
# 2294               1
# 1622               1
# 999                1
# Name: Denominator, Length: 801, dtype: int64

# %%
.insert
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-a0cd0ed7d38f> in <module>
# ----> 1 help.insert
#
# AttributeError: '_Helper' object has no attribute 'insert'
